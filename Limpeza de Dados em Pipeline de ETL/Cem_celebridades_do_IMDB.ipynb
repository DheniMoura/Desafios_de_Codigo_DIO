# %% [markdown]
# # Context
# The dataset contains information about the top 100 celebrities from the IMDb site. The data has been collected through web scraping from the 'https://m.imdb.com/chart/starmeter/' webpage.
#
# The dataset consists of the following columns:
#
# Rank: The ranking position of the celebrity based on their popularity and starmeter rating.
# Name: The name of the celebrity.
# Date_of_birth: The date of birth of the celebrity.
# Height: The height of the celebrity.
# Roles: The roles played by the celebrity, including actor, director, producer, and other related roles.
# Awards: The number of awards the celebrity has received, including both wins and nominations.
# Famous_for: The movie or show for which the celebrity is widely recognized and known.
# Birth_place: The birthplace of the celebrity.
# This dataset provides valuable information about the top 100 celebrities, including their rankings, personal details such as birth date and height, their roles in the entertainment industry, their recognition through awards, the projects they are famous for, and their birthplaces. It can be used for various analyses and insights into the popularity and achievements of these celebrities.
#
# # Purpose
# As part of the challenge of creating an ETL pipeline, we will clean up this dataset in order to make it ready for further analysis of the data.

# %% [markdown]
# # Extract
# Extracting the original data from a .csv file.

# %%
import pandas as pd

# %%
df = pd.read_csv('celeb_data.csv')
df.head()
# Out:
#    Rank              Name Date_of_birth           height  \
# 0     1     Anya Chalotra    1995-07-21   5′ 6″ (1.68 m)
# 1     2     Hayley Atwell    1982-04-05  5′ 6½″ (1.69 m)
# 2     3  Rebecca Ferguson    1983-10-19   5′ 5″ (1.65 m)
# 3     4     Vanessa Kirby    1988-04-18   5′ 7″ (1.70 m)
# 4     5        Tom Cruise    1962-07-03   5′ 7″ (1.70 m)
#
#                                     Role                           Awards  \
# 0                            ['Actress']                            1 win
# 1              ['Actress', 'Soundtrack']                   15 nominations
# 2  ['Actress', 'Soundtrack', 'Producer']                           9 wins
# 3  ['Actress', 'Soundtrack', 'Producer']    5 wins , 43 nominations total
# 4      ['Actor', 'Director', 'Producer']  59 wins , 108 nominations total
#
#                            Famous_for  \
# 0                         The Witcher
# 1  Captain America: The First Avenger
# 2                The Greatest Showman
# 3                           The Crown
# 4                             Top Gun
#
#                                  Birth_place
# 0  Wolverhampton, Staffordshire, England, UK
# 1                        London, England, UK
# 2                                     Sweden
# 3                        London, England, UK
# 4                    Syracuse, New York, USA

# %%
df.tail()
# Out:
#     Rank                Name Date_of_birth           height  \
# 95    96   Elizabeth Debicki    1990-08-24  6′ 2¾″ (1.90 m)
# 96    97      John Krasinski    1979-10-20   6′ 3″ (1.91 m)
# 97    98          Idris Elba    1972-09-06  6′ 2½″ (1.89 m)
# 98    99  Chloë Grace Moretz    1997-02-10   5′ 4″ (1.63 m)
# 99   100         Juno Temple    1989-07-21   5′ 2″ (1.57 m)
#
#                                      Role                           Awards  \
# 95                ['Actress', 'Producer']    6 wins , 38 nominations total
# 96      ['Actor', 'Director', 'Producer']   18 wins , 79 nominations total
# 97        ['Actor', 'Producer', 'Writer']  30 wins , 102 nominations total
# 98  ['Actress', 'Soundtrack', 'Producer']                          28 wins
# 99              ['Actress', 'Soundtrack']    6 wins , 19 nominations total
#
#                 Famous_for                   Birth_place
# 95        The Great Gatsby                 Paris, France
# 96  Tom Clancy's Jack Ryan    Newton, Massachusetts, USA
# 97     Beasts of No Nation  Hackney, London, England, UK
# 98                Kick-Ass         Atlanta, Georgia, USA
# 99               Atonement           London, England, UK

# %% [markdown]
# # Transform
# Performing data verification and cleaning.

# %%
df.shape
# Out:
# (100, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           100 non-null    int64
#  1   Name           100 non-null    object
#  2   Date_of_birth  100 non-null    object
#  3   height         96 non-null     object
#  4   Role           100 non-null    object
#  5   Awards         98 non-null     object
#  6   Famous_for     100 non-null    object
#  7   Birth_place    98 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 6.4+ KB

# %%
# Checkin for duplicates values
df.duplicated().sum()
# Out:
# 0

# %%
# Checkin for null values
pd.isnull(df).sum()
# Out:
# Rank             0
# Name             0
# Date_of_birth    0
# height           4
# Role             0
# Awards           2
# Famous_for       0
# Birth_place      2
# dtype: int64

# %%
# Finding the null data
df[pd.isna(df['height'])]
# Out:
#     Rank                   Name Date_of_birth height  \
# 15    16      Ariana Greenblatt    2007-08-27    NaN
# 75    76             Miss Benny    1999-02-19    NaN
# 77    78  Christopher McQuarrie    1968-10-25    NaN
# 79    80            Ayo Edebiri    1995-10-03    NaN
#
#                                   Role                          Awards  \
# 15                         ['Actress']                    1 nomination
# 75           ['Actress', 'Soundtrack']                             NaN
# 77  ['Director', 'Producer', 'Writer']  10 wins , 17 nominations total
# 79   ['Actress', 'Producer', 'Writer']   3 wins , 13 nominations total
#
#             Famous_for                 Birth_place
# 15              Barbie               New York, USA
# 75           Glamorous                         NaN
# 77  The Usual Suspects  Princeton, New Jersey, USA
# 79            The Bear  Boston, Massachusetts, USA

# %%
# Finding the null data
df[pd.isna(df['Awards'])]
# Out:
#     Rank        Name Date_of_birth       height  \
# 33    34    Liz Katz    1988-07-08  5′ (1.52 m)
# 75    76  Miss Benny    1999-02-19          NaN
#
#                                  Role Awards   Famous_for  \
# 33  ['Actress', 'Director', 'Writer']    NaN  Guest House
# 75          ['Actress', 'Soundtrack']    NaN    Glamorous
#
#                   Birth_place
# 33  Randolph, New Jersey, USA
# 75                        NaN

# %%
# Finding the null data
df[pd.isna(df['Birth_place'])]
# Out:
#     Rank               Name Date_of_birth           height  \
# 24    25  Kingsley Ben-Adir    1986-11-20  5′ 7½″ (1.71 m)
# 75    76         Miss Benny    1999-02-19              NaN
#
#                          Role                          Awards Famous_for  \
# 24                  ['Actor']  10 wins , 14 nominations total     The OA
# 75  ['Actress', 'Soundtrack']                             NaN  Glamorous
#
#    Birth_place
# 24         NaN
# 75         NaN

# %% [markdown]
# The .dropna() approach will make us lose 6/100. We will then use the technique to fill in the missing data as appropriate for each column.

# %%
values = {'height': '-', 'Awards': 'without nominations', 'Birth_place': 'uninformed'}
df.fillna(value=values, inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Rank             0
# Name             0
# Date_of_birth    0
# height           0
# Role             0
# Awards           0
# Famous_for       0
# Birth_place      0
# dtype: int64

# %%
df.shape
# Out:
# (100, 8)

# %%
# knowing the data types
df.dtypes
# Out:
# Rank              int64
# Name             object
# Date_of_birth    object
# height           object
# Role             object
# Awards           object
# Famous_for       object
# Birth_place      object
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Rank                Name Date_of_birth           height  \
# 0      1       Anya Chalotra    1995-07-21   5′ 6″ (1.68 m)
# 1      2       Hayley Atwell    1982-04-05  5′ 6½″ (1.69 m)
# 2      3    Rebecca Ferguson    1983-10-19   5′ 5″ (1.65 m)
# 3      4       Vanessa Kirby    1988-04-18   5′ 7″ (1.70 m)
# 4      5          Tom Cruise    1962-07-03   5′ 7″ (1.70 m)
# ..   ...                 ...           ...              ...
# 95    96   Elizabeth Debicki    1990-08-24  6′ 2¾″ (1.90 m)
# 96    97      John Krasinski    1979-10-20   6′ 3″ (1.91 m)
# 97    98          Idris Elba    1972-09-06  6′ 2½″ (1.89 m)
# 98    99  Chloë Grace Moretz    1997-02-10   5′ 4″ (1.63 m)
# 99   100         Juno Temple    1989-07-21   5′ 2″ (1.57 m)
#
#                                      Role                           Awards  \
# 0                             ['Actress']                            1 win
# 1               ['Actress', 'Soundtrack']                   15 nominations
# 2   ['Actress', 'Soundtrack', 'Producer']                           9 wins
# 3   ['Actress', 'Soundtrack', 'Producer']    5 wins , 43 nominations total
# 4       ['Actor', 'Director', 'Producer']  59 wins , 108 nominations total
# ..                                    ...                              ...
# 95                ['Actress', 'Producer']    6 wins , 38 nominations total
# 96      ['Actor', 'Director', 'Producer']   18 wins , 79 nominations total
# 97        ['Actor', 'Producer', 'Writer']  30 wins , 102 nominations total
# 98  ['Actress', 'Soundtrack', 'Producer']                          28 wins
# 99              ['Actress', 'Soundtrack']    6 wins , 19 nominations total
#
#                             Famous_for  \
# 0                          The Witcher
# 1   Captain America: The First Avenger
# 2                 The Greatest Showman
# 3                            The Crown
# 4                              Top Gun
# ..                                 ...
# 95                    The Great Gatsby
# 96              Tom Clancy's Jack Ryan
# 97                 Beasts of No Nation
# 98                            Kick-Ass
# 99                           Atonement
#
#                                   Birth_place
# 0   Wolverhampton, Staffordshire, England, UK
# 1                         London, England, UK
# 2                                      Sweden
# 3                         London, England, UK
# 4                     Syracuse, New York, USA
# ..                                        ...
# 95                              Paris, France
# 96                 Newton, Massachusetts, USA
# 97               Hackney, London, England, UK
# 98                      Atlanta, Georgia, USA
# 99                        London, England, UK
#
# [100 rows x 8 columns]>

# %%
df.rename(columns={"height" : "Height"})
# Out:
#     Rank                Name Date_of_birth           Height  \
# 0      1       Anya Chalotra    1995-07-21   5′ 6″ (1.68 m)
# 1      2       Hayley Atwell    1982-04-05  5′ 6½″ (1.69 m)
# 2      3    Rebecca Ferguson    1983-10-19   5′ 5″ (1.65 m)
# 3      4       Vanessa Kirby    1988-04-18   5′ 7″ (1.70 m)
# 4      5          Tom Cruise    1962-07-03   5′ 7″ (1.70 m)
# ..   ...                 ...           ...              ...
# 95    96   Elizabeth Debicki    1990-08-24  6′ 2¾″ (1.90 m)
# 96    97      John Krasinski    1979-10-20   6′ 3″ (1.91 m)
# 97    98          Idris Elba    1972-09-06  6′ 2½″ (1.89 m)
# 98    99  Chloë Grace Moretz    1997-02-10   5′ 4″ (1.63 m)
# 99   100         Juno Temple    1989-07-21   5′ 2″ (1.57 m)
#
#                                      Role                           Awards  \
# 0                             ['Actress']                            1 win
# 1               ['Actress', 'Soundtrack']                   15 nominations
# 2   ['Actress', 'Soundtrack', 'Producer']                           9 wins
# 3   ['Actress', 'Soundtrack', 'Producer']    5 wins , 43 nominations total
# 4       ['Actor', 'Director', 'Producer']  59 wins , 108 nominations total
# ..                                    ...                              ...
# 95                ['Actress', 'Producer']    6 wins , 38 nominations total
# 96      ['Actor', 'Director', 'Producer']   18 wins , 79 nominations total
# 97        ['Actor', 'Producer', 'Writer']  30 wins , 102 nominations total
# 98  ['Actress', 'Soundtrack', 'Producer']                          28 wins
# 99              ['Actress', 'Soundtrack']    6 wins , 19 nominations total
#
#                             Famous_for  \
# 0                          The Witcher
# 1   Captain America: The First Avenger
# 2                 The Greatest Showman
# 3                            The Crown
# 4                              Top Gun
# ..                                 ...
# 95                    The Great Gatsby
# 96              Tom Clancy's Jack Ryan
# 97                 Beasts of No Nation
# 98                            Kick-Ass
# 99                           Atonement
#
#                                   Birth_place
# 0   Wolverhampton, Staffordshire, England, UK
# 1                         London, England, UK
# 2                                      Sweden
# 3                         London, England, UK
# 4                     Syracuse, New York, USA
# ..                                        ...
# 95                              Paris, France
# 96                 Newton, Massachusetts, USA
# 97               Hackney, London, England, UK
# 98                      Atlanta, Georgia, USA
# 99                        London, England, UK
#
# [100 rows x 8 columns]

# %% [markdown]
# # LOAD
# Update the clean data.

# %%
df.to_csv('new_celeb_data.csv', index=False)

# %%
new_df = pd.read_csv('new_celeb_data.csv')
new_df.head()
# Out:
#    Rank              Name Date_of_birth           height  \
# 0     1     Anya Chalotra    1995-07-21   5′ 6″ (1.68 m)
# 1     2     Hayley Atwell    1982-04-05  5′ 6½″ (1.69 m)
# 2     3  Rebecca Ferguson    1983-10-19   5′ 5″ (1.65 m)
# 3     4     Vanessa Kirby    1988-04-18   5′ 7″ (1.70 m)
# 4     5        Tom Cruise    1962-07-03   5′ 7″ (1.70 m)
#
#                                     Role                           Awards  \
# 0                            ['Actress']                            1 win
# 1              ['Actress', 'Soundtrack']                   15 nominations
# 2  ['Actress', 'Soundtrack', 'Producer']                           9 wins
# 3  ['Actress', 'Soundtrack', 'Producer']    5 wins , 43 nominations total
# 4      ['Actor', 'Director', 'Producer']  59 wins , 108 nominations total
#
#                            Famous_for  \
# 0                         The Witcher
# 1  Captain America: The First Avenger
# 2                The Greatest Showman
# 3                           The Crown
# 4                             Top Gun
#
#                                  Birth_place
# 0  Wolverhampton, Staffordshire, England, UK
# 1                        London, England, UK
# 2                                     Sweden
# 3                        London, England, UK
# 4                    Syracuse, New York, USA
